# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (18, 6)
plt.rcParams['font.size'] = 10
life = pd.read_csv(r"C:\Users\Rahul Teja\OneDrive\Desktop\Dhruthzuci\Wellbeing_and_lifestyle_data.csv")

# %%
life.describe()
# Out:
#        FRUITS_VEGGIES  PLACES_VISITED   CORE_CIRCLE  SUPPORTING_OTHERS  \
# count    15972.000000    15972.000000  15972.000000       15972.000000
# mean         2.922677        5.232970      5.508077           5.616454
# std          1.442694        3.311912      2.840334           3.242021
# min          0.000000        0.000000      0.000000           0.000000
# 25%          2.000000        2.000000      3.000000           3.000000
# 50%          3.000000        5.000000      5.000000           5.000000
# 75%          4.000000        8.000000      8.000000          10.000000
# max          5.000000       10.000000     10.000000          10.000000
#
#        SOCIAL_NETWORK   ACHIEVEMENT      DONATION     BMI_RANGE  \
# count    15972.000000  15972.000000  15972.000000  15972.000000
# mean         6.474267      4.000751      2.715314      1.410656
# std          3.086672      2.755837      1.851586      0.491968
# min          0.000000      0.000000      0.000000      1.000000
# ...

# %% [markdown]
# Bar Chart to show distribution of happiness score:

# %%
life['WORK_LIFE_BALANCE_SCORE'].plot(kind='hist', bins=30, colormap='plasma')
plt.ylabel('Frequency')
plt.xlabel('Work-Life Balance Score')
plt.title('Work-Life Balance Distribution')
# Out:
# Text(0.5, 1.0, 'Work-Life Balance Distribution')

# %% [markdown]
# Removing unnecessary columns

# %%
newLife = life.drop(['Timestamp', 'FLOW', 'DAILY_SHOUTING', 'LOST_VACATION'], axis = 1)

# %% [markdown]
# Analyzing Top 5000 Happiness scores.

# %%
topfivethousand = newLife[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION',
 'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION', 'AGE', 'GENDER',
 'WORK_LIFE_BALANCE_SCORE']].sort_values('WORK_LIFE_BALANCE_SCORE', ascending=False).head(5000)

# %% [markdown]
# Analyzing the Top 5000 Happiness Scores according to Age.

# %%
topfivethousand['AGE'].value_counts().plot(kind='pie', colormap='plasma')
topfivethousand['AGE'].value_counts()
# Out:
# AGE
# 21 to 35        1612
# 36 to 50        1473
# 51 or more      1381
# Less than 20     534
# Name: count, dtype: int64

# %% [markdown]
# Analyzing the Top 5000 Happiness Scores according to Gender.

# %%
topfivethousand['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
topfivethousand['GENDER'].value_counts()
# Out:
# GENDER
# Female    3182
# Male      1818
# Name: count, dtype: int64

# %% [markdown]
# Analysing Top 5000 happiness scores accoring to sleep hours.

# %%
topfivethousand['SLEEP_HOURS'].value_counts().plot(kind='bar', colormap='plasma')
topfivethousand['SLEEP_HOURS'].value_counts()
# Out:
# SLEEP_HOURS
# 7     1868
# 8     1673
# 6      808
# 9      351
# 5      176
# 10      90
# 4       32
# 1        1
# 3        1
# Name: count, dtype: int64

# %% [markdown]
# Analyzing Bottom 5000 happiness scores.

# %%
botfivethousand = newLife[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION',
 'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION', 'AGE', 'GENDER',
 'WORK_LIFE_BALANCE_SCORE']].sort_values('WORK_LIFE_BALANCE_SCORE', ascending=True).head(5000)

# %% [markdown]
# Analyzing Bottom 5000 Happiness scores according to Age.

# %%
botfivethousand['AGE'].value_counts().plot(kind='pie', colormap='plasma')
botfivethousand['AGE'].value_counts()
# Out:
# AGE
# 21 to 35        2148
# 36 to 50        1469
# 51 or more       799
# Less than 20     584
# Name: count, dtype: int64

# %% [markdown]
# Analyzing the Bottom 5000 Happiness Scores according to Gender.

# %%
botfivethousand['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
botfivethousand['GENDER'].value_counts()
# Out:
# GENDER
# Female    2936
# Male      2064
# Name: count, dtype: int64

# %% [markdown]
# Analysing Bottom 5000 Happiness score according to sleep hours.

# %%
botfivethousand['SLEEP_HOURS'].value_counts().plot(kind='bar', colormap='plasma')
botfivethousand['SLEEP_HOURS'].value_counts()
# Out:
# SLEEP_HOURS
# 7     1506
# 6     1337
# 8      981
# 5      497
# 9      310
# 4      155
# 10     145
# 3       38
# 2       16
# 1       15
# Name: count, dtype: int64

# %% [markdown]
# Life Vision Analysis (For how many years ahead is your life
# vision clear for?)

# %% [markdown]
# Top 5000 Score vs Life Vision
# 1. Life vision and happiness score
# 2. Life vision and age

# %%
newLife['LIVE_VISION'].value_counts().plot(kind='bar', colormap='plasma')
# Out:
# <Axes: xlabel='LIVE_VISION'>

# %%
topfivethousand['LIVE_VISION'].value_counts().plot(kind='bar', colormap='plasma')
# Out:
# <Axes: xlabel='LIVE_VISION'>

# %%
botfivethousand['LIVE_VISION'].value_counts().plot(kind='bar', colormap='plasma')
# Out:
# <Axes: xlabel='LIVE_VISION'>

# %% [markdown]
# Stress vs. Happiness

# %%
topfivethousand['DAILY_STRESS'].value_counts().plot(kind='pie', colormap='plasma')
topfivethousand['DAILY_STRESS'].value_counts()
# Out:
# DAILY_STRESS
# 2    1332
# 3    1295
# 1    1197
# 4     548
# 0     387
# 5     241
# Name: count, dtype: int64

# %%
botfivethousand['DAILY_STRESS'].value_counts().plot(kind='pie', colormap='plasma')
botfivethousand['DAILY_STRESS'].value_counts()
# Out:
# DAILY_STRESS
# 3    1298
# 4    1285
# 5    1175
# 2     736
# 1     403
# 0     103
# Name: count, dtype: int64

# %% [markdown]
# Weekly Time spent on passion vs score.

# %%
topfivethousand['TIME_FOR_PASSION'].value_counts().plot(kind='bar', colormap='plasma')
topfivethousand['TIME_FOR_PASSION'].value_counts()
# Out:
# TIME_FOR_PASSION
# 2     667
# 3     596
# 8     575
# 5     571
# 4     551
# 10    516
# 6     490
# 1     461
# 7     376
# 9     126
# 0      71
# Name: count, dtype: int64

# %%
botfivethousand['TIME_FOR_PASSION'].value_counts().plot(kind='bar', colormap='plasma')
botfivethousand['TIME_FOR_PASSION'].value_counts()
# Out:
# TIME_FOR_PASSION
# 1     1498
# 0     1323
# 2      880
# 3      504
# 4      294
# 5      178
# 6      151
# 8       76
# 7       52
# 10      33
# 9       11
# Name: count, dtype: int64

# %% [markdown]
# Average Values of the top 5000

# %%
topMean = topfivethousand[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION',
 'WORK_LIFE_BALANCE_SCORE']].mean()

print(topMean)
# Out:
# FRUITS_VEGGIES                3.6522
# DAILY_STRESS                     inf
# PLACES_VISITED                 7.229
# CORE_CIRCLE                    7.195
# SUPPORTING_OTHERS             7.7274
# SOCIAL_NETWORK                7.8802
# ACHIEVEMENT                    5.838
# DONATION                      3.6812
# TODO_COMPLETED                7.2732
# DAILY_STEPS                   7.0798
# LIVE_VISION                    5.558
# SLEEP_HOURS                   7.2758
# SUFFICIENT_INCOME              1.907
# PERSONAL_AWARDS               7.5572
# TIME_FOR_PASSION              5.0216
# WEEKLY_MEDITATION              7.642
# WORK_LIFE_BALANCE_SCORE    717.56004
# dtype: object

# %%
botMean = botfivethousand[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION',
 'WORK_LIFE_BALANCE_SCORE']].mean()

print(botMean)
# Out:
# FRUITS_VEGGIES                2.1814
# DAILY_STRESS                     inf
# PLACES_VISITED                3.1678
# CORE_CIRCLE                   3.8464
# SUPPORTING_OTHERS             3.6032
# SOCIAL_NETWORK                4.9614
# ACHIEVEMENT                   2.3404
# DONATION                       1.764
# TODO_COMPLETED                3.9984
# DAILY_STEPS                   4.2886
# LIVE_VISION                   2.0728
# SLEEP_HOURS                   6.7836
# SUFFICIENT_INCOME              1.498
# PERSONAL_AWARDS               3.9752
# TIME_FOR_PASSION              1.8286
# WEEKLY_MEDITATION             4.8078
# WORK_LIFE_BALANCE_SCORE    615.06928
# dtype: object

# %%
categories = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
topMeanVal = [3.6522, 7.229, 7.195, 7.7274, 7.8802,5.838,3.6812,7.2732,7.0798,5.558,7.2758,1.907,7.5572,5.0216,7.642]
plt.rcParams['figure.figsize'] = [25.50, 5.50]
plt.rcParams["figure.autolayout"] = True
plt.bar(categories, topMeanVal, width=.5)
# Out:
# <BarContainer object of 15 artists>

# %%
categories = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
botMeanVal = [2.1814,3.1678,3.8464,3.6032,4.9614,2.3404,1.764,3.9984,4.2886,2.0728,6.7836,1.498,3.9752,1.8286,4.8078]
plt.rcParams['figure.figsize'] = [25.50, 5.50]
plt.rcParams["figure.autolayout"] = True
plt.bar(categories, botMeanVal, width=.5)
# Out:
# <BarContainer object of 15 artists>

# %%
barWidth=.5
labels = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
 'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
topMeans = [3.6522, 7.229, 7.195, 7.7274, 7.8802,5.838,3.6812,7.2732,7.0798,5.558,7.2758,1.907,7.5572,5.0216,7.642]
botMeans = [2.1814,3.1678,3.8464,3.6032,4.9614,2.3404,1.764,3.9984,4.2886,2.0728,6.7836,1.498,3.9752,1.8286,4.8078]
width = .35
x = np.arange(len(labels))
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, botMeans, width, label='Bottom Means')
rects2 = ax.bar(x + width/2, topMeans, width, label='Top Means')
ax.set_ylabel('Scores')
ax.set_xticks(x, labels)
ax.legend()
ax.set_title('Average scores per question for the top and bottom 1000 individuals')
# Out:
# Text(0.5, 1.0, 'Average scores per question for the top and bottom 1000 individuals')

# %% [markdown]
# Analyzing for 21-35 Age Group

# %%
youngGroup = newLife.loc[newLife['AGE'] == '21 to 35']
youngGroup
# Out:
#        FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 7                   3            4               5            3
# 8                   5            3               6            4
# 11                  1            4               3            8
# 12                  2            2              10            5
# 14                  3            3               2            3
# ...               ...          ...             ...          ...
# 15965               5            4               2            4
# 15968               3            3               6            8
# 15969               4            3               0           10
# 15970               1            1              10            8
# 15971               5            4               0            2
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 7                      5               7            4         0          1
# ...

# %%
youngGroup['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Young Age Group with High Happiness Scores.

# %%
youngHigh = youngGroup.loc[youngGroup['WORK_LIFE_BALANCE_SCORE'] >= 732.1 ]
youngHigh
# Out:
#        FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 34                  4            2              10            6
# 70                  4            3              10           10
# 92                  5            3               8            1
# 202                 2            1              10            8
# 214                 3            1               5            9
# ...               ...          ...             ...          ...
# 15765               5            0              10            5
# 15771               3            2               5           10
# 15804               5            3              10           10
# 15898               4            3               8            8
# 15918               4            3              10           10
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 34                    10               8           10         2          1
# ...

# %%
yhMean = youngHigh[['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE','SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS','TIME_FOR_PASSION', 'WEEKLY_MEDITATION']].mean()
yhMean
# Out:
# FRUITS_VEGGIES       4.003367
# PLACES_VISITED       8.727273
# CORE_CIRCLE          8.175084
# SUPPORTING_OTHERS    8.939394
# SOCIAL_NETWORK       8.700337
# ACHIEVEMENT          7.185185
# DONATION             3.989899
# TODO_COMPLETED       7.814815
# DAILY_STEPS          8.249158
# LIVE_VISION          6.511785
# SLEEP_HOURS          7.454545
# SUFFICIENT_INCOME    1.929293
# PERSONAL_AWARDS      8.471380
# TIME_FOR_PASSION     6.767677
# WEEKLY_MEDITATION    8.572391
# dtype: float64

# %%
categories = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE','SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
 'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS','TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
plt.rcParams['figure.figsize'] = [25.50, 5.50]
plt.rcParams["figure.autolayout"] = True
plt.bar(categories, yhMean, width=.5)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# Comparing the Overall top group to the top of the 21-35 age group.

# %%
barWidth = .5
labels = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE','SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 
'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS','TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
topMeans = [3.6522, 7.229, 7.195, 7.7274, 7.8802,5.838,3.6812,7.2732,7.0798,5.558,7.2758,1.907,7.5572,5.0216,7.642]
width = .35
x = np.arange(len(labels))
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, yhMean, width, label='Young 75th Percentile Means')
rects2 = ax.bar(x + width/2, topMeans, width, label='Top Means')
ax.set_ylabel('Scores')
ax.set_xticks(x, labels)
ax.legend()
ax.set_title('Average scores per question for the top and bottom 1000 individuals')
# Out:
# Text(0.5, 1.0, 'Average scores per question for the top and bottom 1000 individuals')
